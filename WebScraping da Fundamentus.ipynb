# %% [markdown]
# # In this project, i made a web scarping in a web site named Fundamentus. This site there are all Stock' codes.

# %% [markdown]
# # 1° Step: Import the Beautiful Soup and others frameworks

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 
from urllib.request import Request,urlopen
from urllib.error import URLError, HTTPError
import pandas as pd

# %% [markdown]
# # 2° Step: Algorithm to show HTML Tag'

# %%
url = 'https://fundamentus.com.br/resultado.php'
headers = {
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36'
}

try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')

except HTTPError as e:
    print(e.status, e.reason)

except URLError as es:
    print(e.reason)

print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3248/2677187335.py in <module>
#       5
#       6 try:
# ----> 7     req = Request(url, headers = headers)
#       8     response = urlopen(req)
#       9     html = response.read()
#
# ~\anaconda3\lib\urllib\request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     324         self.data = data
#     325         self._tunnel_host = None
# --> 326         for key, value in headers.items():
#     327             self.add_header(key, value)
#     328         if origin_req_host is None:
#
# AttributeError: 'set' object has no attribute 'items'

# %% [markdown]
# # 3° On the body website, find the assets names

# %%
assets_code = []
for stock_code in soup.body.findAll('a'):
    assets_code.append(stock_code.getText())    
print(assets_code)
# Out:
# ['', 'empresa', 'fii', 'Página inicial', 'Investimento consciente', 'Mais Opções', 'Fatos Relevantes', 'Últimos Resultados', 'FII - Pesquisar Imóveis', 'Entre em contato', 'Fundamentus Mobile', 'Papel', 'Cotação', 'P/L', 'P/VP', 'PSR', 'Div.Yield', 'P/Ativo', 'P/Cap.Giro', 'P/EBIT', 'P/Ativ Circ.Liq', 'EV/EBIT', 'EV/EBITDA', 'Mrg Ebit', 'Mrg. Líq.', 'Liq. Corr.', 'ROIC', 'ROE', 'Liq.2meses', 'Patrim. Líq', 'Dív.Brut/ Patrim.', 'Cresc. Rec.5a', 'CSTB4', 'CFLU4', 'PORP4', 'MNSA4', 'IVTT3', 'CLAN3', 'CSTB3', 'POPR4', 'PMET3', 'MNSA3', 'GNDI3', 'APER3', 'CASH3', 'PLDN4', 'DASA3', 'RCSL3', 'LCSA4', 'BHGR3', 'RJCP3', 'ABYA3', 'PITI4', 'MAPT4', 'MAPT3', 'RCSL4', 'LCSA3', 'MAGG3', 'TCNO3', 'TCNO4', 'LINX3', 'BNCA3', 'NORD3', 'ARTR3', 'FRTA3', 'AMIL3', 'BRTP3', 'IDVL11', 'EMBR3', 'PEFX5', 'PEFX3', 'TOYB4', 'IMBI3', 'CLAN4', 'TOYB3', 'EBTP3', 'EBTP4', 'FBRA4', 'BRTP4', 'ELMD3', 'ITEC3', 'BAHI4', 'IMBI4', 'PRTX3', 'OMGE3', 'DFVA3', 'ASTA4', 'VLID3', 'RRRP3', 'VGOR4', 'CRBM3', 'ORVR3', 'DFVA4', 
# ...

# %%
assets_code[32:-15]
#data_stock_code = pd.DataFrame(data = assets_code[32:-15], columns = ["Code_Stocks"])
#data_stock_code
# Out:
# ['CSTB4',
#  'CFLU4',
#  'PORP4',
#  'MNSA4',
#  'IVTT3',
#  'CLAN3',
#  'CSTB3',
#  'POPR4',
#  'PMET3',
#  'MNSA3',
#  'GNDI3',
#  'APER3',
#  'CASH3',
#  'PLDN4',
#  'DASA3',
#  'RCSL3',
#  'LCSA4',
#  'BHGR3',
#  'RJCP3',
#  'ABYA3',
#  'PITI4',
#  'MAPT4',
#  'MAPT3',
#  'RCSL4',
#  'LCSA3',
#  'MAGG3',
#  'TCNO3',
#  'TCNO4',
#  'LINX3',
#  'BNCA3',
#  'NORD3',
#  'ARTR3',
#  'FRTA3',
#  'AMIL3',
#  'BRTP3',
#  'IDVL11',
#  'EMBR3',
#  'PEFX5',
#  'PEFX3',
#  'TOYB4',
#  'IMBI3',
#  'CLAN4',
#  'TOYB3',
#  'EBTP3',
#  'EBTP4',
#  'FBRA4',
#  'BRTP4',
#  'ELMD3',
#  'ITEC3',
#  'BAHI4',
#  'IMBI4',
#  'PRTX3',
#  'OMGE3',
#  'DFVA3',
#  'ASTA4',
#  'VLID3',
#  'RRRP3',
#  'VGOR4',
#  'CRBM3',
#  'ORVR3',
#  'DFVA4',
#  'BAHI5',
#  'TXRX3',
#  'TAMM4',
#  'TAMM3',
#  'ECOR3',
#  'TELB3',
#  'HBSA3',
#  'DTCY3',
#  'CRBM7',
#  'WMBY3',
#  'TDBH4',
#  'TANC4',
#  'SMFT3',
#  'HBRE3',
#  'CCIM3',
#  'TDBH3',
#  'GBIO33',
#  'SCLO3',
#  'LECO4',
#  'SEDU3',
#  'TESA3',
#  'WEST3',
# ...

# %%
#df_stocks = data_stock_code.to_csv('assets_code.csv', sep= ';')

# %% [markdown]
# # 4° Clean the tickers had expired

# %%
new_url = "https://fundamentus.com.br/detalhes.php?papel="

# %%
for sot in "https://fundamentus.com.br/detalhes.php?papel={assets_code[32:-15]}"
# Out:
#   File "C:\Users\danie\AppData\Local\Temp/ipykernel_3248/1962809406.py", line 1
#     for sot in "https://fundamentus.com.br/detalhes.php?papel={assets_code[32:-15]}"
#                                                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # My WebScrapping Project : Assets Codes

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 
from urllib.request import Request,urlopen
from urllib.error import URLError, HTTPError
import pandas as pd

url = 'https://fundamentus.com.br/resultado.php'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'
}

try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')

except HTTPError as e:
    print(e.status, e.reason)

except URLError as es:
    print(e.reason)

    
assets_code = []
for stock_code in soup.body.findAll('a'):
    assets_code.append(stock_code.getText())

data_stock_code = pd.DataFrame(data = assets_code[32:-15], columns = ["Code_Stocks"])
df_stocks = data_stock_code.to_csv('Data/assets_code.csv', sep= ';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3248/608068490.py in <module>
#      28
#      29 data_stock_code = pd.DataFrame(data = assets_code[32:-15], columns = ["Code_Stocks"])
# ---> 30 df_stocks = data_stock_code.to_csv('Data/assets_code.csv', sep= ';')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ...

# %%
table = soup.body.findAll(name='table')
table_stocks = pd.read_html(str(table))
df = pd.DataFrame(data = table_stocks, )
df_table_stocks = df_table.to_csv('Data/assets_code.csv', sep= ';')
